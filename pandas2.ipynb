# %% [markdown]
# <a href="https://colab.research.google.com/github/SachiSachu/1stop/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('cars_ds_final.csv')
df.head()
# Out:
#    Unnamed: 0  Make      Model  ... Welcome_Lights Battery Electric_Range
# 0           0  Tata  Nano Genx  ...            NaN     NaN            NaN
# 1           1  Tata  Nano Genx  ...            NaN     NaN            NaN
# 2           2  Tata  Nano Genx  ...            NaN     NaN            NaN
# 3           3  Tata  Nano Genx  ...            NaN     NaN            NaN
# 4           4  Tata  Nano Genx  ...            NaN     NaN            NaN
#
# [5 rows x 141 columns]

# %% [markdown]
# 2. Plotting the top 5 brands

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-80c72379bb65> in <module>()
# ----> 1 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
data.plot(x='brand', y = 'freq', kind= 'bar', figsize=(15,5))

# %% [markdown]
# 1. Top 5 brands

# %%
data.sort_values(by='freq', ascending=False).head()# we sort values by frequency in decending order
# Out:
#             brand  freq
# 3   Maruti Suzuki   149
# 4         Hyundai   130
# 10       Mahindra   119
# 0            Tata   100
# 6          Toyota    82

# %%
data = []
for brand in df['Make'].unique(): #we will go with each unique brand 
  data.append([brand, len(df[df['Make']==brand])]) # we store the value in list with its count like data = [['tata',12],['hundai', 123]]
data #this will print the 2D list
# Out:
# [['Tata', 100],
#  ['Datsun', 15],
#  ['Renault', 36],
#  ['Maruti Suzuki', 149],
#  ['Hyundai', 130],
#  ['Premier', 6],
#  ['Toyota', 82],
#  ['Nissan', 29],
#  ['Volkswagen', 34],
#  ['Ford', 43],
#  ['Mahindra', 119],
#  ['Fiat', 23],
#  ['Honda', 64],
#  ['Jeep', 28],
#  ['Isuzu', 5],
#  ['Skoda', 43],
#  ['Audi', 31],
#  [nan, 0],
#  ['Dc', 1],
#  ['Mini', 10],
#  ['Volvo', 18],
#  ['Jaguar', 22],
#  ['Bmw', 37],
#  ['Land Rover', 10],
#  ['Porsche', 14],
#  ['Lexus', 10],
#  ['Maserati', 9],
#  ['Lamborghini', 13],
#  ['Bentley', 6],
#  ['Ferrari', 8],
#  ['Aston Martin', 3],
#  ['Bugatti', 2],
#  ['Bajaj', 2],
#  ['Icml', 11],
#  ['Force', 6],
#  ['Mg', 13],
#  ['Kia', 21],
#  ['Land Rover Rover', 27],
#  ['Mitsubishi', 7],
#  ['Maruti Suzuki R', 14]]

# %%
data = pd.DataFrame(data, columns=['brand', 'freq']) #this will set the data frame with columns
data
# Out:
#                brand  freq
# 0               Tata   100
# 1             Datsun    15
# 2            Renault    36
# 3      Maruti Suzuki   149
# 4            Hyundai   130
# 5            Premier     6
# 6             Toyota    82
# 7             Nissan    29
# 8         Volkswagen    34
# 9               Ford    43
# 10          Mahindra   119
# 11              Fiat    23
# 12             Honda    64
# 13              Jeep    28
# 14             Isuzu     5
# 15             Skoda    43
# 16              Audi    31
# 17               NaN     0
# 18                Dc     1
# 19              Mini    10
# 20             Volvo    18
# 21            Jaguar    22
# 22               Bmw    37
# 23        Land Rover    10
# 24           Porsche    14
# 25             Lexus    10
# 26          Maserati     9
# 27       Lamborghini    13
# 28           Bentley     6
# 29           Ferrari     8
# 30      Aston Martin     3
# 31           Bugatti     2
# 32             Bajaj     2
# ...
